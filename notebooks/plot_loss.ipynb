# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
train = np.load("./checkpoints/train_loss_scheduler.npy")
val = np.load("./checkpoints/val_loos_scheduler.npy")

# %%
fig, ax = plt.subplots()
ax.set_yscale("log")
ax.plot(train)
ax.plot(val)
ax.set_ylabel("MSE")
ax.set_xlabel("training epoch (x50)")
ax.grid()
plt.draw()
plt.show()
